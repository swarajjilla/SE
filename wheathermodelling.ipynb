# %%
#Hard coding

import numpy as np
import matplotlib.pyplot as plt

def solve_quadratic(a, b, c):
    discriminant = b**2 - 4*a*c
    if discriminant < 0:
        return None, None
    root1 = (-b + np.sqrt(discriminant)) / (2*a)
    root2 = (-b - np.sqrt(discriminant)) / (2*a)
    return root1, root2

def plot_quadratic(a, b, c):
    x = np.linspace(-10, 10, 400)
    y = a*x**2 + b*x + c
    plt.plot(x, y)
    plt.title(f'Quadratic Equation: {a}x^2 + {b}x + {c}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.show()

# Hard-coded variables
a, b, c = 1, -3, 2

# Solving and plotting
root1, root2 = solve_quadratic(a, b, c)
print(f"Roots: {root1}, {root2}")
plot_quadratic(a, b, c)
# Out:
# Roots: 2.0, 1.0

# %%
#hard codeing (multiple)

import numpy as np
import matplotlib.pyplot as plt

def solve_quadratic(a, b, c):
    discriminant = b**2 - 4*a*c
    if discriminant < 0:
        return None, None
    root1 = (-b + np.sqrt(discriminant)) / (2*a)
    root2 = (-b - np.sqrt(discriminant)) / (2*a)
    return root1, root2

def plot_quadratic(a, b, c):
    x = np.linspace(-10, 10, 400)
    y = a*x**2 + b*x + c
    plt.plot(x, y)
    plt.title(f'Quadratic Equation: {a}x^2 + {b}x + {c}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.show()

# Multiple hard-coded sets of variables
coefficients = [
    (1, -3, 2),
    (1, -2, 1),
    (1, 0, -4)
]

for a, b, c in coefficients:
    root1, root2 = solve_quadratic(a, b, c)
    print(f"Roots for {a}x^2 + {b}x + {c}: {root1}, {root2}")
    plot_quadratic(a, b, c)
# Out:
# Roots for 1x^2 + -3x + 2: 2.0, 1.0
# Roots for 1x^2 + -2x + 1: 1.0, 1.0
# Roots for 1x^2 + 0x + -4: 2.0, -2.0

# %%
#keyboard single input

import numpy as np
import matplotlib.pyplot as plt

def solve_quadratic(a, b, c):
    discriminant = b**2 - 4*a*c
    if discriminant < 0:
        return None, None
    root1 = (-b + np.sqrt(discriminant)) / (2*a)
    root2 = (-b - np.sqrt(discriminant)) / (2*a)
    return root1, root2

def plot_quadratic(a, b, c):
    x = np.linspace(-10, 10, 400)
    y = a*x**2 + b*x + c
    plt.plot(x, y)
    plt.title(f'Quadratic Equation: {a}x^2 + {b}x + {c}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.show()

# Keyboard input for a single set of variables
a = float(input("Enter coefficient a: "))
b = float(input("Enter coefficient b: "))
c = float(input("Enter coefficient c: "))

root1, root2 = solve_quadratic(a, b, c)
print(f"Roots: {root1}, {root2}")
plot_quadratic(a, b, c)
# Out:
# Roots: None, None

# %%
#keyboard multiple inputs

import numpy as np
import matplotlib.pyplot as plt

def solve_quadratic(a, b, c):
    discriminant = b**2 - 4*a*c
    if discriminant < 0:
        return None, None
    root1 = (-b + np.sqrt(discriminant)) / (2*a)
    root2 = (-b - np.sqrt(discriminant)) / (2*a)
    return root1, root2

def plot_quadratic(a, b, c):
    x = np.linspace(-10, 10, 400)
    y = a*x**2 + b*x + c
    plt.plot(x, y)
    plt.title(f'Quadratic Equation: {a}x^2 + {b}x + {c}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.show()

# Keyboard input for multiple sets of variables
num_sets = int(input("Enter the number of sets of coefficients: "))

coefficients = []
for i in range(num_sets):
    a = float(input(f"Enter coefficient a for set {i+1}: "))
    b = float(input(f"Enter coefficient b for set {i+1}: "))
    c = float(input(f"Enter coefficient c for set {i+1}: "))
    coefficients.append((a, b, c))

for a, b, c in coefficients:
    root1, root2 = solve_quadratic(a, b, c)
    print(f"Roots for {a}x^2 + {b}x + {c}: {root1}, {root2}")
    plot_quadratic(a, b, c)
# Out:
# Roots for 4.0x^2 + 3.0x + 4.0: None, None
# Roots for 2.0x^2 + 3.0x + 4.0: None, None
# Roots for 3.0x^2 + 3.0x + 4.0: None, None

# %%
#reading from file single input

import numpy as np
import matplotlib.pyplot as plt

def solve_quadratic(a, b, c):
    discriminant = b**2 - 4*a*c
    if discriminant < 0:
        return None, None
    root1 = (-b + np.sqrt(discriminant)) / (2*a)
    root2 = (-b - np.sqrt(discriminant)) / (2*a)
    return root1, root2

def plot_quadratic(a, b, c):
    x = np.linspace(-10, 10, 400)
    y = a*x**2 + b*x + c
    plt.plot(x, y)
    plt.title(f'Quadratic Equation: {a}x^2 + {b}x + {c}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.show()

# Reading from a file for a single set of variables
with open('coefficients.txt', 'r') as file:
    line = file.readline()
    a, b, c = map(float, line.split())

root1, root2 = solve_quadratic(a, b, c)
print(f"Roots: {root1}, {root2}")
plot_quadratic(a, b, c)
# Out:
# Roots: None, None

# %%
import numpy as np
import matplotlib.pyplot as plt

def solve_quadratic(a, b, c):
    discriminant = b**2 - 4*a*c
    if discriminant < 0:
        return None, None
    root1 = (-b + np.sqrt(discriminant)) / (2*a)
    root2 = (-b - np.sqrt(discriminant)) / (2*a)
    return root1, root2

def plot_quadratic(a, b, c):
    x = np.linspace(-10, 10, 400)
    y = a*x**2 + b*x + c
    plt.plot(x, y)
    plt.title(f'Quadratic Equation: {a}x^2 + {b}x + {c}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.show()

# Reading from a file for multiple sets of variables
coefficients = []
with open('multiple_coefficients.txt', 'r') as file:
    for line in file:
        a, b, c = map(float, line.split())
        coefficients.append((a, b, c))

for a, b, c in coefficients:
    root1, root2 = solve_quadratic(a, b, c)
    print(f"Roots for {a}x^2 + {b}x + {c}: {root1}, {root2}")
    plot_quadratic(a, b, c)
# Out:
# Roots for 1.0x^2 + -3.0x + 6.0: None, None
